# %%
from load_project_config import load_project_config
from load_data import load_project_data
from plot_data import plot_project_data
from prepare_data import prepare_model_data
from train_and_run_model import train_and_run_model
from post_process import process_model_data, plot_results, plot_all_results

# %%
df = load_project_data(data_dir='./data')
plot_project_data(df)

# %%
df = load_project_data(data_dir='./data')
config = load_project_config('config_LSTMModel_long.yml')
model_data = prepare_model_data(config, df)
model_predictions = train_and_run_model(config, model_data)
plot_df = process_model_data(config, df, model_predictions)
plot_results(config, df, plot_df, model_data)
# Out:
# DataLoader ready for training!
# Model 1, Epoch 64/64, Loss: 0.0482
# Model 2, Epoch 64/64, Loss: 0.0332
# Model 3, Epoch 64/64, Loss: 0.0125
# Model 4, Epoch 64/64, Loss: 0.0143
# Model 5, Epoch 64/64, Loss: 0.0252
# Model 6, Epoch 64/64, Loss: 0.0059
# Model 7, Epoch 64/64, Loss: 0.0211
# Model 8, Epoch 64/64, Loss: 0.0083
# Model 9, Epoch 64/64, Loss: 0.0374
# Model 10, Epoch 64/64, Loss: 0.0116
# Model 11, Epoch 64/64, Loss: 0.0123
# Model 12, Epoch 64/64, Loss: 0.0235
# Model 13, Epoch 64/64, Loss: 0.0134
# Model 14, Epoch 64/64, Loss: 0.0361
# Model 15, Epoch 64/64, Loss: 0.0093
# Model 16, Epoch 64/64, Loss: 0.0379
# Data saved to ./output/LSTMModel_training_274_days.csv

# %%
df = load_project_data(data_dir='./data')
config = load_project_config('config_LSTMModel_short.yml')
model_data = prepare_model_data(config, df)
model_predictions = train_and_run_model(config, model_data)
plot_df = process_model_data(config, df, model_predictions)
plot_results(config, df, plot_df, model_data)
# Out:
# DataLoader ready for training!
# Model 1, Epoch 64/64, Loss: 0.0295
# Model 2, Epoch 64/64, Loss: 0.0139
# Model 3, Epoch 64/64, Loss: 0.0170
# Model 4, Epoch 64/64, Loss: 0.0036
# Model 5, Epoch 64/64, Loss: 0.0046
# Model 6, Epoch 64/64, Loss: 0.0118
# Model 7, Epoch 64/64, Loss: 0.0072
# Model 8, Epoch 64/64, Loss: 0.0041
# Model 9, Epoch 64/64, Loss: 0.0069
# Model 10, Epoch 64/64, Loss: 0.0061
# Model 11, Epoch 64/64, Loss: 0.0055
# Model 12, Epoch 64/64, Loss: 0.0112
# Model 13, Epoch 64/64, Loss: 0.0030
# Model 14, Epoch 64/64, Loss: 0.0043
# Model 15, Epoch 64/64, Loss: 0.0076
# Model 16, Epoch 64/64, Loss: 0.0036
# Data saved to ./output/LSTMModel_training_60_days.csv

# %%
df = load_project_data(data_dir='./data')
config = load_project_config('config_LSTM_combo_Model_long.yml')
model_data = prepare_model_data(config, df)
model_predictions = train_and_run_model(config, model_data)
plot_df = process_model_data(config, df, model_predictions)
plot_results(config, df, plot_df, model_data)
# Out:
# DataLoader ready for training!
# Model 1, Epoch 64/64, Loss: 0.0174
# Model 2, Epoch 64/64, Loss: 0.0031
# Model 3, Epoch 64/64, Loss: 0.0043
# Model 4, Epoch 64/64, Loss: 0.0015
# Model 5, Epoch 64/64, Loss: 0.0034
# Model 6, Epoch 64/64, Loss: 0.0011
# Model 7, Epoch 64/64, Loss: 0.0011
# Model 8, Epoch 64/64, Loss: 0.0016
# Model 9, Epoch 64/64, Loss: 0.0013
# Model 10, Epoch 64/64, Loss: 0.0013
# Model 11, Epoch 64/64, Loss: 0.0014
# Model 12, Epoch 64/64, Loss: 0.0010
# Model 13, Epoch 64/64, Loss: 0.0015
# Model 14, Epoch 64/64, Loss: 0.0015
# Model 15, Epoch 64/64, Loss: 0.0013
# Model 16, Epoch 64/64, Loss: 0.0018
# Data saved to ./output/LSTM_combo_Model_training_274_days.csv

# %%
df = load_project_data(data_dir='./data')
config = load_project_config('config_LSTM_combo_Model_short.yml')
model_data = prepare_model_data(config, df)
model_predictions = train_and_run_model(config, model_data)
plot_df = process_model_data(config, df, model_predictions)
plot_results(config, df, plot_df, model_data)
# Out:
# DataLoader ready for training!
# Model 1, Epoch 64/64, Loss: 0.0228
# Model 2, Epoch 64/64, Loss: 0.0092
# Model 3, Epoch 64/64, Loss: 0.0032
# Model 4, Epoch 64/64, Loss: 0.0018
# Model 5, Epoch 64/64, Loss: 0.0020
# Model 6, Epoch 64/64, Loss: 0.0042
# Model 7, Epoch 64/64, Loss: 0.0013
# Model 8, Epoch 64/64, Loss: 0.0004
# Model 9, Epoch 64/64, Loss: 0.0025
# Model 10, Epoch 64/64, Loss: 0.0004
# Model 11, Epoch 64/64, Loss: 0.0004
# Model 12, Epoch 64/64, Loss: 0.0002
# Model 13, Epoch 64/64, Loss: 0.0011
# Model 14, Epoch 64/64, Loss: 0.0021
# Model 15, Epoch 64/64, Loss: 0.0004
# Model 16, Epoch 64/64, Loss: 0.0006
# Data saved to ./output/LSTM_combo_Model_training_60_days.csv

# %%
df = load_project_data(data_dir='./data')
plot_all_results(df)
