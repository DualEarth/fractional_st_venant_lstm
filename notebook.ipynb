# %%
from load_project_config import load_project_config
from load_data import load_project_data
from plot_data import plot_project_data
from prepare_data import prepare_model_data
from train_and_run_model import train_and_run_model
import post_process as pp

# %%
df = load_project_data(data_dir='./data')
plot_project_data(df)

# %%
df = load_project_data(data_dir='./data')
config = load_project_config('./config/LSTMModel_long.yml')
model_data = prepare_model_data(config, df)
model_predictions = train_and_run_model(config, model_data)
plot_df = pp.process_model_data(config, df, model_predictions)
pp.plot_results(config, df, plot_df, model_data)
# Out:
# DataLoader ready for training!
# Data saved to ./output/LSTMModel_training_274_days.csv

# %%
df = load_project_data(data_dir='./data')
config = load_project_config('./config/LSTMModel_short.yml')
model_data = prepare_model_data(config, df)
model_predictions = train_and_run_model(config, model_data)
plot_df = pp.process_model_data(config, df, model_predictions)
pp.plot_results(config, df, plot_df, model_data)
# Out:
# DataLoader ready for training!
# Data saved to ./output/LSTMModel_training_60_days.csv

# %%
df = load_project_data(data_dir='./data')
config = load_project_config('./config/LSTM_combo_Model_long.yml')
model_data = prepare_model_data(config, df)
model_predictions = train_and_run_model(config, model_data)
plot_df = pp.process_model_data(config, df, model_predictions)
pp.plot_results(config, df, plot_df, model_data)
# Out:
# DataLoader ready for training!
# Data saved to ./output/LSTM_combo_Model_training_274_days.csv

# %%
df = load_project_data(data_dir='./data')
config = load_project_config('./config/LSTM_combo_Model_short.yml')
model_data = prepare_model_data(config, df)
model_predictions = train_and_run_model(config, model_data)
plot_df = pp.process_model_data(config, df, model_predictions)
pp.plot_results(config, df, plot_df, model_data)
# Out:
# DataLoader ready for training!
# Data saved to ./output/LSTM_combo_Model_training_60_days.csv

# %%
df = load_project_data(data_dir='./data')
pp.plot_all_results(df)
pp.calculate_metrics(df)
# Out:
#                                 Model        RMSE        R2       NSE  \
# 0   LSTM_combo_Model_training_60_days  299.527545  0.845410  0.845410
# 1         LSTMModel_training_274_days  107.039245  0.980258  0.980258
# 2          LSTMModel_training_60_days  213.047224  0.921790  0.921790
# 3  LSTM_combo_Model_training_274_days  135.970570  0.968144  0.968144
#
#         KGE
# 0  0.826590
# 1  0.966573
# 2  0.845263
# 3  0.949307
